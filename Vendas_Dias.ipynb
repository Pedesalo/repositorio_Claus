# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
n_samples=50

# %%
data = {
    'Data': pd.date_range(start='2023-01-01',periods=n_samples,freq='D'),
    'Vendas':np.random.randint(50,200,size=n_samples),
    'Lucro':np.random.randint(10,50,size=n_samples)
}

# %%
df=pd.DataFrame(data)

# %%
df["Margem"]=df['Lucro']/df["Vendas"]

# %%
df['Margem'].min()
# Out:
# np.float64(0.06321839080459771)

# %%
df['Margem'].max()
# Out:
# np.float64(0.7619047619047619)

# %%
plt.figure(figsize=(10,6))
plt.plot(df['Data'], df['Vendas'], marker='o', linestyle='-', color='m')
